# %% [markdown]
# <a href="https://colab.research.google.com/github/Anele1977/stepik_auto_tests_python/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn import tree
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from IPython.display import SVG
from graphviz import Source
from IPython.display import display

from IPython.display import HTML
style = "<style>{width:50% !important; height:10% !important;}</style>"
HTML(style)


titanic_date = pd.read_csv('/content/titanic.csv')
X = titanic_date.drop(['PassengerId', 'Survived', 'Name', 'Ticket', 'Cabin'], axis=1)
y = titanic_date.Survived
X = pd.get_dummies(X)
X = X.fillna({'Age': X.Age.median()})

# %%
X.head()
# Out:
#    Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  Embarked_C  \
# 0       3  22.0      1      0   7.2500           0         1           0
# 1       1  38.0      1      0  71.2833           1         0           1
# 2       3  26.0      0      0   7.9250           1         0           0
# 3       1  35.0      1      0  53.1000           1         0           0
# 4       3  35.0      0      0   8.0500           0         1           0
#
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1

# %%
from sklearn.model_selection import train_test_split

# %%
X_train = train_test_split(X, y, test_size=0.33,random_state=42)
X_test = train_test_split(X,y, test_size=0.33,random_state=42)
y_train = train_test_split(X,y, test_size=0.33,random_state=42)
y_test = train_test_split(X,y, test_size=0.33,random_state=42)

# %%
X_train.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-73020798007e> in <cell line: 1>()
# ----> 1 X_train.head()
#
# NameError: name 'X_train' is not defined

# %%
clf = tree.DecisionTreeClassifier(criterion='entropy')

# %%
clf.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
tree.plot_tree(clf, feature_names=list(X),
               class_names=['Died', 'Survived'],
               filled=True);

# %% [markdown]
# # Новый раздел

# %% [markdown]
# # Новый раздел
